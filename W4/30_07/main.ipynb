# %%
import numpy as np

data = np.array([1, 3, 4, 4])
mean = np.mean(data)
variance = np.var(data)
standard_deviation = np.std(data)

print(mean, variance, standard_deviation)
# Out:
# 3.0 1.5 1.224744871391589

# %%
var1 = np.array([1, 3, 4, 4])
var2 = np.array([1, 2, 3, 2])

#Compute covariance
print("Covariance: \n", np.cov(var1, var2))

#Compute correlation coffecient
print("Correlation: \n", np.corrcoef(var1, var2))
# Out:
# Covariance:
#  [[2.         1.        ]
#  [1.         0.66666667]]
# Correlation:
#  [[1.        0.8660254]
#  [0.8660254 1.       ]]
